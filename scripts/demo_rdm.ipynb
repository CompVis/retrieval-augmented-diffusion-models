# %%
if "CHANGED_DIR" not in globals():
    CHANGED_DIR = True
    # %cd ..
# Out:
# /export/compvis-nfs/user/jomuelle/publish/nitro

# %%
import datetime
from pathlib import Path

import numpy as np
import torch
import torchvision
from clip import tokenize
from einops import rearrange
from matplotlib import pyplot as plt
from omegaconf import OmegaConf
from PIL import Image
from pytorch_lightning import seed_everything
from tqdm.auto import tqdm, trange

from ipywidgets import interact

from ldm.util import instantiate_from_config

# %% [markdown]
# # Load Model

# %% [markdown]
# Assume that all models are in the given format in `models/rdm/**` with a `config.yaml` and `model.ckpt` file. You will need to adjust this for self-trained models

# %%
# choose which model we want to load

paths = [p.parent for p in Path("models/rdm/").glob("**/model.ckpt")]
paths.sort()
@interact(model_path=paths)
def choose_model(model_path: str):
    global model_dir, config_path, ckpt_path
    model_dir = model_path
    config_path = model_dir / "config.yaml"
    ckpt_path = model_dir / "model.ckpt"
    assert config_path.is_file(), f"Did not found config at {config_path}"
# Out:
# interactive(children=(Dropdown(description='model_path', options=(PosixPath('models/rdm/ffhq'), PosixPath('mod…

# %%
# actually loading the model

# Setting load patches from neighbors (requires open images/database to be downloaded)
load_patch_dataset = True

# Load model configuration and change some settings
config = OmegaConf.load(config_path)
config.model.params.retrieval_cfg.params.load_patch_dataset = load_patch_dataset
# Don't load anything on any gpu until told to do so
# alternatively call with `CUDA_VISIBLE_DEVICES=...`
config.model.params.retrieval_cfg.params.gpu = False
config.model.params.retrieval_cfg.params.retriever_config.params.device = "cpu"

# Load state dict
pl_sd = torch.load(ckpt_path, map_location="cpu")
global_step = pl_sd["global_step"]

# Initialize model
model = instantiate_from_config(config.model)

# Apply checkpoint
m, u = model.load_state_dict(pl_sd["state_dict"], strict=False)
if len(m) > 0:
    print(f"Missing keys: \n {m}")
    print("Missing unconditional_guidance_vex is expected")
if len(u) > 0:
    print(f"Unexpected keys: \n {u}")
print("Loaded model.")

# Eval mode
model = model.eval()
# Out:
# MinimalRETRODiffusion: Running in eps-prediction mode
# faiss not available. Go on and hope for the best
# Attention attention: num_heads: 12; dim_head: 32
# Attention attention: num_heads: 12; dim_head: 32
# Attention attention: num_heads: 18; dim_head: 32
# Attention attention: num_heads: 18; dim_head: 32
# Attention attention: num_heads: 30; dim_head: 32
# Attention attention: num_heads: 30; dim_head: 32
# Attention attention: num_heads: 30; dim_head: 32
# Attention attention: num_heads: 30; dim_head: 32
# Attention attention: num_heads: 30; dim_head: 32
# Attention attention: num_heads: 30; dim_head: 32
# Attention attention: num_heads: 18; dim_head: 32
# Attention attention: num_heads: 18; dim_head: 32
# Attention attention: num_heads: 18; dim_head: 32
# Attention attention: num_heads: 12; dim_head: 32
# Attention attention: num_heads: 12; dim_head: 32
# Attention attention: num_heads: 12; dim_head: 32
# DiffusionWrapper has 400.92 M params.
# Keeping EMAs of 690.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 3, 64, 64) = 12288 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Training MinimalRETRODiffusion as an unconditional model.
# RETRODiffusionWrapper: Wrapping diffusion model for RETRO training. For multimodal data, conditionings will be chained in a list and all fed into the 'SpatialTransformer' via different cross-attention blocks.
# Keeping EMAs of 690.
# Loading nn_memory from "nn_memory/oi_imagenet.p"
# Loaded nn_memory of size 3382022
# No module named 'torch_geometric'
# ### need to install torch-sparse.
# Building Full OpenImages Dataset. Get a Coffee.
# Constructing Train Data: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:09<00:00,  1.07it/s]
# Remove Corrupts: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 253/253 [00:19<00:00, 13.07it/s]
# Max number of patches per image is 3
# Min number of patches per image is 2
# N samples in PatcherDataset is 20000000
# Batch size: 100; patch_div: 3; dset_batch_size: 33
# Load saved patch embedding from "/export/compvis-nfs/group/datasets/retrieval_datasets/2022-03-10T11-39-35-FullOpenImagesTrain-ClipImageRetriever-256"
# Setting timestamp to "2022-03-10T11-39-35"
# Start prefetching...
# Loading datapool from 1 individual files.: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:54<00:00, 114.65s/it]
# Loading datapool from 1 individual files.: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:56<00:00, 116.36s/it]
# Loading datapool from 1 individual files.: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:57<00:00, 117.45s/it]
# Loading datapool from 1 individual files.: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:57<00:00, 117.46s/it]
# Loading datapool from 1 individual files.: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:57<00:00, 117.75s/it]
# Loading datapool from 1 individual files.: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:57<00:00, 117.94s/it]
# Loading datapool from 1 individual files.: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:57<00:00, 117.98s/it]
# Loading datapool from 1 individual files.: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:58<00:00, 118.05s/it]
# Loading datapool from 1 individual files.: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:58<00:00, 118.17s/it]
# Loading datapool from 1 individual files.: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:58<00:00, 118.22s/it]
# Prefetching complete. [183.81437134742737 sec.]
# Finished loading of retrieval database of length 20000000.
# No predefined savedir for searcher, setting to /export/compvis-nfs/group/datasets/retrieval_datasets/searchers/FullOpenImagesTrain_0020M_256
# Setting guiding vex shape to (,) (assuming clip nn encoder)
# Initializing unconditional guidance vector
# Missing keys:
#  ['unconditional_guidance_vex']
# Missing unconditional_guidance_vex is expected
# Loaded model.

# %% [markdown]
# # Image Utility Functions

# %%
def rescale(x: torch.Tensor) -> torch.Tensor:
    return (x + 1.)/2.

def bchw_to_np(x, grid=False, clamp=False):
    if grid:
        x = torchvision.utils.make_grid(x, nrow=min(x.shape[0], 4))[None, ...]
    x = rescale(rearrange(x.detach().cpu(), "b c h w -> b h w c"))
    if clamp:
        x.clamp_(0, 1)
    return x.numpy()

def custom_to_pil(x):
    if isinstance(x,np.ndarray):
        x = torch.from_numpy(x)
    x = x.detach().cpu()
    x = torch.clamp(x, -1., 1.)
    x = (x + 1.) / 2.
    x = x.permute(1, 2, 0).numpy()
    x = (255 * x).astype(np.uint8)
    x = Image.fromarray(x)
    if not x.mode == "RGB":
        x = x.convert("RGB")
    return x

# %% [markdown]
# # Sampling Settings

# %%
if torch.cuda.is_available():
    options = ["cpu"] + [f"cuda:{x}" for x in range(torch.cuda.device_count())]
    @interact(device_id=options)
    def device_selector(device_id):
        global device, model
        device = torch.device(device_id)
        model = model.to(device)
        # retriever is no nn.Module, so device changes are not passed through
        model.retriever.retriever.to(device)
else:
    device = torch.device("cpu")
# Out:
# interactive(children=(Dropdown(description='device_id', options=('cpu', 'cuda:0', 'cuda:1', 'cuda:2', 'cuda:3'…

# %%
# How many images to generate at once
batch_size = 8
# repeat sampling this number of times
n_runs = 2
# set to number to seed samples
seed = None
# whether to increase the guidance parameter by one for each run
increase_guidance = False
# Keep same queries for each run
keep_qids = True

if seed is not None and (not increase_guidance) and r_runs > 1:
    print("Warning: You will get the same images each run")

# classifier free (transformer) guidance
guidance_scale = 2.0
# Number of steps
steps = 100
# top_m sampling as described in the paper (either in (0, 1.] or {1, ..., len(database)}
top_m          = 0.005
# number of neighbors drawn for sampling
k_nn           = 4

if top_m > 1.0:
    # top_m should be int if a fixed number of images is given
    top_m = int(top_m)

# caption used for sampling
caption       = "A fox, high quality photograph"
# use the caption only, no neighbors
only_caption  = True
# omit query in query based sampling (mutually exclusive with only_caption)
omit_query  = False
# Use proposal distribution weights (else sample uniform under top_m)
use_weights   = False

# %% [markdown]
# # Sampling

# %% [markdown]
# RDMs provide two sampling methods `sample_from_rdata` and `sample_with_query`.
#
# - `sample_from_rdata` samples a pseudo query from **r**etrieval **data** and then samples the model. This corresponds to unconditional sampling in the paper.
# - `sample_with_query` need a predefined query, e.g. an enconded query-text, retrieves neighbors and uses them for sampling.

# %%
# sample_from_rdata based
with torch.no_grad():
    if keep_qids:
        qids = model.get_qids(top_m, batch_size, use_weights=use_weights)
    else:
        qids = None

    sampling_start = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")

    for n in trange(n_runs):
        if seed is not None:
            seed_everything(seed)

        tqdm.write("Sampling query and neighbors (wait for the sampling to start)")

        # Here is where the magic happens:
        logs = model.sample_from_rdata(
                batch_size,
                qids=qids,
                k_nn=k_nn,
                return_nns=load_patch_dataset,
                use_weights=use_weights,
                memsize=top_m,
                unconditional_guidance_scale=guidance_scale,
                ddim_steps=steps,
                ddim=True,
                unconditional_retro_guidance_label=0.,
        )
        plotting_keys = []
        for key in logs:
            if (key == "samples_with_sampled_nns"
                    or (key == "sampled_nns" and (n==0 or not keep_qids))
                    ):
                plotting_keys.append(key)
        plotting_keys.sort()
        
        tqdm.write(f"Run {n+1}/{n_runs}")
        for idx, key in enumerate(plotting_keys):
            try:
                fig = plt.figure(figsize=(10, 10))
                plt.imshow(bchw_to_np(logs[key], grid=True, clamp=True)[0])
                plt.axis("off")
                plt.title(key)
                plt.show()
            except Exception as e:
                tqdm.write(f"logging {key} not possible due to the following:")
                tqdm.write(str(e))

        if increase_guidance:
            guidance_scale += 1.0
            tqdm.write(f"New guidance scale: {guidance_scale}")

    print("Done")
# Out:
# Top-M Sampling with memory size 16910
#   0%|          | 0/2 [00:00<?, ?it/s]
# Sampling query and neighbors (wait for the sampling to start)
# training searcher...
# load pretrained searcher from /export/compvis-nfs/group/datasets/retrieval_datasets/searchers/FullOpenImagesTrain_0020M_256
# Finished loading searcher.
# done training searcher
# torch.Size([8, 4, 512])
# Plotting: Switched to EMA weights
# Using unconditonal diffusion guidance with scale 2.0
# Data shape for DDIM sampling is (8, 3, 64, 64), eta 0.0
# Running DDIM Sampling with 100 timesteps
# DDIM Sampler:   0%|          | 0/100 [00:00<?, ?it/s]
# Plotting: Restored training weights
# Run 1/2
# Sampling query and neighbors (wait for the sampling to start)
# torch.Size([8, 4, 512])
# Plotting: Switched to EMA weights
# Using unconditonal diffusion guidance with scale 2.0
# Data shape for DDIM sampling is (8, 3, 64, 64), eta 0.0
# Running DDIM Sampling with 100 timesteps
# DDIM Sampler:   0%|          | 0/100 [00:00<?, ?it/s]
# Plotting: Restored training weights
# Run 2/2
# Done

# %%
# sample with query
with torch.no_grad():
    qids = None

    sampling_start = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
    query_embeddings = None
    nn_embeddings = None
    tokenized = tokenize([caption]*batch_size).to(model.device)
    clip = model.retriever.retriever.model
    query_embeddings = clip.encode_text(tokenized).cpu()
    del tokenized

    for n in trange(n_runs):
        if seed is not None:
            seed_everything(seed)

        tqdm.write("Sampling query and neighbors (wait for the sampling to start)")

        # Here is where the magic happens:
        logs = model.sample_with_query(
                query=query_embeddings,
                query_embedded=True,
                k_nn=k_nn if not only_caption else 1,
                return_nns=load_patch_dataset and not only_caption,
                use_weights=use_weights,
                unconditional_guidance_scale=guidance_scale,
                ddim_steps=steps,
                ddim=True,
                unconditional_retro_guidance_label=0.,
                omit_query=omit_query and not only_caption,
        )
        
        tqdm.write(f"Run {n+1}/{n_runs}")
        for key in logs.keys():
            try:
                fig = plt.figure(figsize=(10, 10))
                plt.imshow(bchw_to_np(logs[key], grid=True, clamp=True)[0])
                plt.axis("off")
                plt.title(key)
                plt.show()
            except Exception as e:
                tqdm.write(f"logging {key} not possible due to the following:")
                tqdm.write(str(e))

        if increase_guidance:
            guidance_scale += 1.0
            tqdm.write(f"New guidance scale: {guidance_scale}")

    print("Done")
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# Sampling query and neighbors (wait for the sampling to start)
# torch.Size([8, 512])
# Query shape is (8, 512)
# torch.Size([8, 1, 512])
# torch.Size([8, 1, 512])
# Plotting: Switched to EMA weights
# Using unconditonal diffusion guidance with scale 2.0
# Data shape for DDIM sampling is (8, 3, 64, 64), eta 0.0
# Running DDIM Sampling with 100 timesteps
# DDIM Sampler:   0%|          | 0/100 [00:00<?, ?it/s]
# Plotting: Restored training weights
# Run 1/2
# Sampling query and neighbors (wait for the sampling to start)
# torch.Size([8, 512])
# Query shape is (8, 512)
# torch.Size([8, 1, 512])
# torch.Size([8, 1, 512])
# Plotting: Switched to EMA weights
# Using unconditonal diffusion guidance with scale 2.0
# Data shape for DDIM sampling is (8, 3, 64, 64), eta 0.0
# Running DDIM Sampling with 100 timesteps
# DDIM Sampler:   0%|          | 0/100 [00:00<?, ?it/s]
# Plotting: Restored training weights
# Run 2/2
# Done
